# %% [markdown]
# # Aula 7
# ## Challenge 3
# ___

# %% [markdown]
# Utilize o conjunto de dados da challenge anterior, relacione dois atributos em um scatter plot que indique a relação entre os mesmos.

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.style.use('seaborn')

# %%
df_pimas = pd.read_csv("data/pima-data-norm-city.csv", index_col=0)
df_pimas.head(5)
# Out:
#     num_preg  glucose_conc  diastolic_bp  insulin   bmi  diab_pred  age  \
# id
# 0          6         148.0     72.000000      0.0  33.6      0.627   50
# 1          1          85.0     66.000000      0.0  26.6      0.351   31
# 2          8         183.0     69.112125      0.0  23.3      0.672   32
# 3          1          89.0     66.000000     94.0  28.1      0.167   21
# 4          0         137.0     40.000000    168.0  43.1      2.288   33
#
#         skin  diabetes        state    city
# id
# 0   1.379000      True  Maharashtra  Mumbai
# 1   1.142600     False  Maharashtra  Mumbai
# 2   0.809136      True  Maharashtra  Mumbai
# 3   0.906200     False  Maharashtra  Mumbai
# 4   1.379000      True  Maharashtra  Mumbai

# %%
sns.lmplot("age", "num_preg", df_pimas)

# %%
sns.lmplot("age", "diab_pred", df_pimas)

# %%
sns.lmplot("age", "glucose_conc", df_pimas)

# %%
sns.lmplot("diab_pred", "glucose_conc", df_pimas, order=2)

# %%
sns.lmplot("insulin", "glucose_conc", df_pimas)

# %%
sns.lmplot("insulin", "diab_pred", df_pimas)

# %%
sns.lmplot("bmi", "diab_pred", df_pimas)
