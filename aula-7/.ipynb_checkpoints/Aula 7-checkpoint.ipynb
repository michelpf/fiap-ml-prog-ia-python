# %% [markdown]
# # Aula 6: Data Visualization

# %% [markdown]
# ## Histogramas
# Quantificando de regisros de um conjunto de dados.

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# /Users/michel.fernandes/anaconda/lib/python3.6/site-packages/joblib/_multiprocessing_helpers.py:28: UserWarning: [Errno 28] No space left on device.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))

# %%
data_set_1 = np.random.randn(200)

# %%
plt.hist(data_set_1)
# Out:
# (array([  3.,   7.,  22.,  32.,  60.,  36.,  26.,   8.,   5.,   1.]),
#  array([-2.84840493, -2.24760832, -1.64681172, -1.04601512, -0.44521851,
#          0.15557809,  0.7563747 ,  1.3571713 ,  1.95796791,  2.55876451,
#          3.15956112]),
#  <a list of 10 Patch objects>)

# %%
data_set_2 = np.random.randn(100)
plt.hist(data_set_2, color="orange")
# Out:
# (array([  2.,   5.,   7.,  12.,  25.,  18.,  14.,   9.,   5.,   3.]),
#  array([-2.65321467, -2.14838432, -1.64355398, -1.13872364, -0.63389329,
#         -0.12906295,  0.37576739,  0.88059774,  1.38542808,  1.89025842,
#          2.39508877]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Normalizado (density=true) os valores vão de 0 a 1.

# %%
plt.hist(data_set_1, color="blue", alpha=0.5, bins=20, density=True)
plt.hist(data_set_2, color="orange", alpha=0.5, bins=20, density=True)
# Out:
# (array([ 0.07923454,  0.        ,  0.03961727,  0.15846908,  0.11885181,
#          0.15846908,  0.27732089,  0.19808635,  0.47540724,  0.51502451,
#          0.63387632,  0.07923454,  0.19808635,  0.35655543,  0.23770362,
#          0.11885181,  0.03961727,  0.15846908,  0.03961727,  0.07923454]),
#  array([-2.65321467, -2.4007995 , -2.14838432, -1.89596915, -1.64355398,
#         -1.39113881, -1.13872364, -0.88630847, -0.63389329, -0.38147812,
#         -0.12906295,  0.12335222,  0.37576739,  0.62818256,  0.88059774,
#          1.13301291,  1.38542808,  1.63784325,  1.89025842,  2.14267359,
#          2.39508877]),
#  <a list of 20 Patch objects>)

# %%
data_set_3 = np.random.randn(4000)
data_set_4 = np.random.randn(4000)

# %%
sns.jointplot(data_set_3, data_set_4)

# %%
sns.jointplot(data_set_3, data_set_4, kind="hex")

# %%
sns.jointplot(data_set_3, data_set_4, kind="kde")

# %%
sns.jointplot(data_set_3, data_set_4, kind="reg")

# %% [markdown]
# ### Box & Violin Plots
# Diagrama de caixa e violino.

# %%
data_set_1 = np.random.randn(200)
data_set_2 = np.random.randn(200)

# %%
sns.boxplot(data=[data_set_1, data_set_2])

# %%
sns.boxplot(data=[data_set_1, data_set_2], whis=np.inf)

# %%
data_frame_1 = pd.read_excel("exemplo.xlsx")
sns.boxplot(data=data_frame_1)

# %%
data_frame_1_norm = data_frame_1.copy()
data_frame_1_norm["Custo"] = data_frame_1["Custo"].div(data_frame_1.sum(axis=1), axis=0)
data_frame_1_norm["Avaliação"] = data_frame_1["Avaliação"].div(data_frame_1.sum(axis=1), axis=0)

# %%
data_frame_1_norm
# Out:
#                 Filme  Avaliação     Custo
# 0            Avengers   0.975000  0.076922
# 1          Avengers 2   0.988235  0.047618
# 2          Avengers 3   0.988235  0.047619
# 3            Iron Man   0.933334  0.142856
# 4          Iron Man 2   0.933334  0.142856
# 5          Iron Man 3   0.750000  0.333333
# 6                Thor   0.988235  0.047618
# 7              Thor 2   0.988235  0.047618
# 8              Thor 3   0.993590  0.032257
# 9     Captain America   0.993590  0.032257
# 10  Captain America 2   0.993590  0.032257
# 11  Captain America 2   0.975000  0.076923

# %%
sns.boxplot(data=data_frame_1_norm)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18, 8)
sns.boxplot(ax=ax, data=data_frame_1_norm, y="Custo", x="Filme")
sns.despine()

# %%
sns.violinplot(data=[data_set_1, data_set_2])

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
fig.set_size_inches(18, 8)
sns.violinplot(ax=ax1, data=[data_set_1, data_set_2])
sns.boxplot(ax=ax2, data=[data_set_1, data_set_2], whis=np.inf)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
fig.set_size_inches(18, 8)
sns.violinplot(ax=ax1, data=[data_set_1, data_set_2], bw=10)
sns.boxplot(ax=ax2, data=[data_set_1, data_set_2], whis=np.inf)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
fig.set_size_inches(18, 8)
sns.violinplot(ax=ax1, data=[data_set_1, data_set_2], bw=0.01)
sns.boxplot(ax=ax2, data=[data_set_1, data_set_2], whis=np.inf)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
fig.set_size_inches(18, 8)
sns.violinplot(ax=ax1, data=[data_set_1, data_set_2], inner="stick")
sns.boxplot(ax=ax2, data=[data_set_1, data_set_2], whis=np.inf)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
fig.set_size_inches(18, 8)
sns.violinplot(ax=ax1, data=[data_set_1, data_set_2], inner="quartile")
sns.boxplot(ax=ax2, data=[data_set_1, data_set_2], whis=np.inf)

# %% [markdown]
# ### Gráficos de Regressão e Scatter Plot
# Gráfico padrão com eixo x e eixo y para encontrar correlações

# %% [markdown]
# #### Regressão

# %%
gorjetas = sns.load_dataset("tips")
gorjetas.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot("total_bill", "tip", gorjetas)

# %%
sns.lmplot("total_bill", "tip", gorjetas,
          scatter_kws={"marker":"x", "color":"blue"},
          line_kws={"linewidth":1, "color": "orange"})

# %%
sns.lmplot("total_bill", "tip", gorjetas, order=2,
          scatter_kws={"marker":"x", "color":"blue"},
          line_kws={"linewidth":1, "color": "orange"})

# %%
gorjetas["porc_tip"]=100*gorjetas["tip"]/gorjetas["total_bill"]
sns.lmplot("size", "porc_tip", gorjetas, x_estimator=np.mean)

# %%
sns.lmplot("total_bill", "porc_tip", gorjetas, hue="sex", markers=["x", "o"])

# %%
sns.lmplot("total_bill", "porc_tip", gorjetas, hue="day")

# %% [markdown]
# #### Scatter Plot e correlação

# %%
data_frame_1
# Out:
#                 Filme  Avaliação   Custo
# 0            Avengers          3  210000
# 1          Avengers 2          4  250000
# 2          Avengers 3          4  400000
# 3            Iron Man          2  200000
# 4          Iron Man 2          2  200000
# 5          Iron Man 3          1  240000
# 6                Thor          4  240000
# 7              Thor 2          4  200000
# 8              Thor 3          5  230000
# 9     Captain America          5  180000
# 10  Captain America 2          5  200000
# 11  Captain America 2          3  280000

# %%
sns.regplot(data=data_frame_1, y="Avaliação", x="Custo")

# %% [markdown]
# ### Line Chart
# Gráfico em linhas para evolução de dados

# %%
data_frame_2 = pd.read_excel("bilheteria.xlsx")

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18, 8)
plt.plot(data_frame_2["Data"], data_frame_2["Bilheteria"])
